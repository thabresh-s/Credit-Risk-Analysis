# %% [markdown]
# <a href="https://colab.research.google.com/github/thabresh-s/Credit-Risk-Analysis/blob/main/Untitled19.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Step 1: Install the necessary libraries
# !pip install pandas matplotlib seaborn quantstats yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.3/41.3 KB 2.4 MB/s eta 0:00:00
# ...

# %%
# Step 2: Import the necessary libraries
import pandas as pd
import quantstats as qs
import yfinance as yf

# %%
# Step 3: Load the TCS stock data into a Pandas DataFrame using yfinance
symbol = "TCS.NS"  # TCS stock symbol on the National Stock Exchange of India
data = yf.download(symbol, start="2015-01-01", end="2021-12-31")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
# Step 4: Calculate the performance metrics using the QuantStats library
qs.extend_pandas()
returns = data['Close'].pct_change()
qs.reports.html(returns, output='tcs_report.html', title='TCS Stock Report')
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# WARNING:matplotlib.font_manager:findfont: Font family 'Arial' not found.
# ...

# %%
# Step 5: Open the HTML report in the Jupyter Notebook
from IPython.core.display import HTML
HTML(filename='tcs_report.html')
# Out:
# <!-- generated by QuantStats for Python -->
# <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="utf-8">
#     <meta http-equiv="X-UA-Compatible" content="IE=edge,chrome=1">
#     <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no">
#     <title>Tearsheet (generated by QuantStats)</title>
#     <meta name="robots" content="noindex, nofollow">
#     <link rel="shortcut icon" href="https://qtpylib.io/favicon.ico" type="image/x-icon">
#     <style>
# ...
